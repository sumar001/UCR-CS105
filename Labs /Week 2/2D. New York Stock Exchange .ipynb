# %% [markdown]
# Name: ???

# %% [markdown]
# This example is based on the EDA example in Doing Data Science Ch. 2. There are 31 datasets named nyt1.csv, nyt2.csv,…,nyt31.csv, which you can find here: https://github.com/oreillymedia/doing_data_science. I have already downloaded the dataset for you to use under the folder: /nytdata
#
# Each file represents one (simulated) day’s worth of ads shown and clicks recorded on the New York Times home page in May 2012. Each row represents a single user. There are five columns: age, gender (0=female, 1=male), number impressions, number clicks, and logged-in.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Lets start off analyzing one file

# %%
df =  pd.read_csv("dds_ch2_nyt/nyt1.csv") # read-in one file 
df.head()
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In
# 0   36       0            3       0          1
# 1   73       1            3       0          1
# 2   30       0            3       0          1
# 3   49       1            3       0          1
# 4   47       1           11       0          1

# %% [markdown]
# Once you have the data loaded, it’s time for some EDA:

# %% [markdown]
# Create a new variable, age_group, that categorizes users as "<18", "18-24", "25-34", "35-44", "45-54", "55-64", and "65+".

# %%
bins= [0,18,25,35,45,55,65,108]
labels = ['<18','18-24','25-34','35-44','45-54','55-64','65+']
df['age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
df['age_group'].value_counts().plot(kind='bar')

# %% [markdown]
# Plot the distributions of number impressions and click-through-rate for these six age categories.

# %%
df.groupby("age_group").mean()["Impressions"].plot(kind='bar')

# %%
df.groupby("age_group").mean()["Clicks"].plot(kind='bar')

# %% [markdown]
# Explore the data and make visual and quantitative comparisons across user segments/demographics (<18-year-old males versus < 18-year-old females or logged-in versus not, for example).

# %%
# TODO

# %% [markdown]
# We analyzed just one file, but the dataset includes 31 files. You can easily aggregate the results into one dataframe as shown below.

# %%
import glob # used to read mutliple-files 
files = glob.glob('dds_ch2_nyt/nyt*.csv')
dfs = []
for file in files:
    df = pd.read_csv(file)
    df['filename'] = file
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#           Age  Gender  Impressions  Clicks  Signed_In               filename
# 0          57       0            4       0          1  dds_ch2_nyt/nyt16.csv
# 1           0       0            6       0          0  dds_ch2_nyt/nyt16.csv
# 2           0       0            8       1          0  dds_ch2_nyt/nyt16.csv
# 3           0       0            6       0          0  dds_ch2_nyt/nyt16.csv
# 4           0       0            5       0          0  dds_ch2_nyt/nyt16.csv
# 5          53       1            5       0          1  dds_ch2_nyt/nyt16.csv
# 6          58       1            8       0          1  dds_ch2_nyt/nyt16.csv
# 7           0       0            9       0          0  dds_ch2_nyt/nyt16.csv
# 8          54       0            6       0          1  dds_ch2_nyt/nyt16.csv
# 9          45       1            0       0          1  dds_ch2_nyt/nyt16.csv
# 10          0       0            7       0          0  dds_ch2_nyt/nyt16.csv
# 11         44       1            4       0          1  dds_ch2_nyt/nyt16.csv
# 12         36       1            6       0          1  dds_ch2_nyt/nyt16.csv
# 13         41       1            4       0          1  dds_ch2_nyt/nyt16.csv
# 14          0       0            2       0          0  dds_ch2_nyt/nyt16.csv
# 15         70       0            3       0          1  dds_ch2_nyt/nyt16.csv
# 16         29       0            4       0          1  dds_ch2_nyt/nyt16.csv
# 17          0       0            9       0          0  dds_ch2_nyt/nyt16.csv
# 18          0       0            3       0          0  dds_ch2_nyt/nyt16.csv
# 19          0       0            9       0          0  dds_ch2_nyt/nyt16.csv
# 20         67       0            6       0          1  dds_ch2_nyt/nyt16.csv
# 21         34       1            6       0          1  dds_ch2_nyt/nyt16.csv
# 22         41       0            4       0          1  dds_ch2_nyt/nyt16.csv
# 23          0       0            5       0          0  dds_ch2_nyt/nyt16.csv
# 24         70       1            5       0          1  dds_ch2_nyt/nyt16.csv
# 25         27       0            3       0          1  dds_ch2_nyt/nyt16.csv
# 26          0       0            5       0          0  dds_ch2_nyt/nyt16.csv
# 27         50       0            5       0          1  dds_ch2_nyt/nyt16.csv
# 28          0       0            4       0          0  dds_ch2_nyt/nyt16.csv
# 29         30       1            6       0          1  dds_ch2_nyt/nyt16.csv
# ...       ...     ...          ...     ...        ...                    ...
# 14905835    0       0            5       0          0  dds_ch2_nyt/nyt27.csv
# 14905836    0       0            4       0          0  dds_ch2_nyt/nyt27.csv
# 14905837    0       0            8       0          0  dds_ch2_nyt/nyt27.csv
# 14905838    0       0            3       0          0  dds_ch2_nyt/nyt27.csv
# 14905839   42       0            6       0          1  dds_ch2_nyt/nyt27.csv
# 14905840   52       1            8       0          1  dds_ch2_nyt/nyt27.csv
# 14905841   53       0            5       0          1  dds_ch2_nyt/nyt27.csv
# 14905842   20       1            6       0          1  dds_ch2_nyt/nyt27.csv
# 14905843    0       0            6       0          0  dds_ch2_nyt/nyt27.csv
# 14905844   47       1            2       0          1  dds_ch2_nyt/nyt27.csv
# 14905845   17       1            2       0          1  dds_ch2_nyt/nyt27.csv
# 14905846   22       0            5       0          1  dds_ch2_nyt/nyt27.csv
# 14905847    0       0            5       0          0  dds_ch2_nyt/nyt27.csv
# 14905848    0       0            5       0          0  dds_ch2_nyt/nyt27.csv
# 14905849   32       0            5       0          1  dds_ch2_nyt/nyt27.csv
# 14905850   81       0            4       0          1  dds_ch2_nyt/nyt27.csv
# 14905851   66       1            8       0          1  dds_ch2_nyt/nyt27.csv
# 14905852   37       0            3       0          1  dds_ch2_nyt/nyt27.csv
# 14905853   61       1            2       0          1  dds_ch2_nyt/nyt27.csv
# 14905854   55       1            5       1          1  dds_ch2_nyt/nyt27.csv
# 14905855    0       0            5       0          0  dds_ch2_nyt/nyt27.csv
# 14905856    0       0            4       0          0  dds_ch2_nyt/nyt27.csv
# 14905857    0       0            4       0          0  dds_ch2_nyt/nyt27.csv
# 14905858   61       0            2       0          1  dds_ch2_nyt/nyt27.csv
# 14905859   47       0            7       0          1  dds_ch2_nyt/nyt27.csv
# 14905860   44       0            6       0          1  dds_ch2_nyt/nyt27.csv
# 14905861   41       0            3       0          1  dds_ch2_nyt/nyt27.csv
# 14905862   19       0            6       0          1  dds_ch2_nyt/nyt27.csv
# 14905863    0       0            4       0          0  dds_ch2_nyt/nyt27.csv
# 14905864    0       0            6       0          0  dds_ch2_nyt/nyt27.csv
#
# [14905865 rows x 6 columns]

# %% [markdown]
# Analyze trends over time since we now have a historic view of the data over 31 days. You can examine how clicks or impresssions change over time by using the filename as the date field.

# %%
# TODO
